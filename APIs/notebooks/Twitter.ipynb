# %% [markdown]
# Much of the code is from this source: (licensed under BSD)
#
# http://nbviewer.ipython.org/github/furukama/Mining-the-Social-Web-2nd-Edition/blob/master/ipynb/Chapter%201%20-%20Mining%20Twitter.ipynb
#
# Before running example you may have to install the Python twitter package.  Type the following on the command line:
#
# pip install twitter

# %%
import twitter
import json

# %%
CONSUMER_KEY = 'EaRL8gSp9ybZWJSRvzG9413Mr'
CONSUMER_SECRET ='2WCgllStptoVMBNiDEPU63bUkZsQWBXgNADN9Vnoa4fIQCMCZg'
OAUTH_TOKEN = '2424473694-vK6qhnnZBdfbUxTAaQGU5x6JodeSYkH8rXu1sXB'
OAUTH_TOKEN_SECRET = 'dKEPgtluCEeUKn1vDRDdxRfweX2K1m1IHvLEvbZUVzccD'

auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,
                           CONSUMER_KEY, CONSUMER_SECRET)

twitter_api = twitter.Twitter(auth=auth)

print auth
print twitter_api

# %%
#q = '#python'
# apparently it only goes back a week!
q = '#raredisease'

count = 100

# See https://dev.twitter.com/docs/api/1.1/get/search/tweets

search_results = twitter_api.search.tweets(q=q, count=count, result_type='mixed')

statuses = search_results['statuses']

# %%
print type(statuses)
print len(statuses)
# Out:
# <type 'list'>
# 100

# %%
print type(statuses)
print type(statuses[0])
# Out:
# <type 'list'>
# <type 'dict'>

# %%
print statuses[0]['text']

numtweets=len(statuses)
print numtweets
# Out:
# Y tú, ya te vacunaste contra la indiferencia?#RareDisease
# #Hazlasvisibles
# #RaroEsIgnorar
# http://t.co/7bigIw6R9i
# Gracias @Esclerodermia #fb
# 100

# %%
for i in range(0,numtweets):
    print statuses[i]['user']['name']
    print statuses[i]['text']
    print
# Out:
# RarasNoInvisibles
# Y tú, ya te vacunaste contra la indiferencia?#RareDisease
# #Hazlasvisibles
# #RaroEsIgnorar
# http://t.co/7bigIw6R9i
# Gracias @Esclerodermia #fb
#
# Rare Disease Day
# #RaiseandJoinHands to show your solidarity with people #LivingWith a #RareDisease! http://t.co/1vkn4yUxrA http://t.co/iSRDNRyElr
#
# Rare Disease Day
# Change your social media profile photos in February http://t.co/pC2n39IwQ7 #RareDisease Day is to share http://t.co/87PHi6AoIb
#
# AdvocacyRSS
# RT @k8tmonaghan: .@advocacyrss Show us your Sunglass Selfie #CystinosisSunglassDay2015 Support #RareDisease https://t.co/2FEqBxtEpb http://…
#
# Rarebase
# Cystinosis Research Foundation Awards $490,373 for Study of Rare Disease | Business Wire http://t.co/9DDioGO64N #RareDisease
#
# Sean Ekins
# Met a Dr today, works for the US government, recently back from Liberia who helped deal with #Ebola, also a #raredisease parent! #humbling
#
# Niemann-Pick C Fund
# ...

# %%
print statuses[0]

# %%
print json.dumps(statuses[0], indent=1)

# %%
import json

print json.dumps(statuses[0], indent=1)
# Out:
# {
#  "contributors": null,
#  "truncated": false,
#  "text": "RT @sam_et_max: Graph Databases in #python http://t.co/ktWtNf6VQh",
#  "in_reply_to_status_id": null,
#  "id": 561865700940464128,
#  "favorite_count": 0,
#  "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#  "retweeted": false,
#  "coordinates": null,
#  "entities": {
#   "symbols": [],
#   "user_mentions": [
#    {
#     "id": 507128812,
#     "indices": [
#      3,
#      14
#     ],
#     "id_str": "507128812",
#     "screen_name": "sam_et_max",
#     "name": "SamEtMax"
#    }
#   ],
#   "hashtags": [
#    {
#     "indices": [
#      35,
#      42
#     ],
#     "text": "python"
#    }
#   ],
#   "urls": [
#    {
#     "url": "http://t.co/ktWtNf6VQh",
#     "indices": [
#      43,
#      65
#     ],
#     "expanded_url": "http://fr.slideshare.net/versae/graph-databases-in-python-pycon-canada-2012",
#     "display_url": "fr.slideshare.net/versae/graph-d\u2026"
# ...
